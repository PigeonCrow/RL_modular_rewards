# %% [markdown]
# |parameter|MILLIDGE|DULBERG|LEE|
# |---|---|---|---|
# |Value function|$V(x) = E(r(x) + \gamma r(x')+ \gamma^2 r(x''))$|$G_t = r_t + \gamma r_t+1 + \gamma^2 (r_t+2)$<br> $Q(s,a) = E_\pi[G_t\|S_t,a_t]$|-|
# |update function||$\pi(s) = argmax_a(Q(s,a))$|-|
# |reward function|$r(x) = \Sigma m_i r_i (x)$|$r_t = D(h_{i,t}) - D(h_{i,t+1})$ <br>$ D(h_{i,t}) = \sqrt[m]{\|h_i^* - h_{i,t}\|}$|-|

# %% [markdown]
# |parameter|Value function|update function|reward function|
# |---|---|---|---|
# |MILLIDGE|$V(x) = E(r(x) + \gamma r(x')+ \gamma^2 r(x''))$|-|$r = \Sigma m_i r_i (x)$|
# |DULBERG|$G_t = r_t + \gamma r_t+1 + \gamma^2 (r_t+2)$<br> $Q(s,a) = E_\pi[G_t\|S_t,a_t]$|$\pi(s) = argmax_a(Q(s,a))$|$r_t = D(h_{i,t}) - D(h_{i,t+1})$ <br>$ D(h_{i,t}) = \sqrt[m]{\|h_i^* - h_{i,t}\|}$|
# |LEE|-|-|-|
