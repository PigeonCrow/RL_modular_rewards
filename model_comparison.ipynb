# %% [markdown]
# |parameter|MILLIDGE|DULBERG|LEE|
# |---|---|---|---|
# |Value function|$V(x) = E(r(x) + \gamma r(x')+ \gamma^2 r(x''))$|$G_t = r_t + \gamma r_t+1 + \gamma^2 (r_t+2)$<br> $Q(s,a) = E_\pi[G_t\|S_t,a_t]$|$V_{i,t} = \omega_i \phi_{i,t}$ <br> $\omega_i = \omega_i + \alpha\phi_{i,t}\delta_t$|
# |reward function|$r(x) = \Sigma m_i r_i (x)$|$r_t = D(h_{i,t}) - D(h_{i,t+1})$ <br>$ D(h_{i,t}) = \sqrt[m]{\|h_i^* - h_{i,t}\|}$|-|
# |Prediction error|$\delta_i(x) = r_i(x) + \gamma V_i(x) - V_i(x)$|$\delta = r_{t+t} + \gamma  max_a Q(s_{t+1,a}) -Q(s_{t,a})$|$\delta_{i,t} = frac{r_t}{N} + \gamma V_{i,t+1} - V_{i,t}$|
# |Policy function|$a = argmax(V(x'))$|$\pi(s) = argmax_a(Q(s,a))$|$a = argmin_a(\delta_{i,t+1})$|

# %% [markdown]
# |parameter|Value function|prediction error|reward function|Policy function|
# |---|---|---|--|---|
# |MILLIDGE|$V(x) = E(r(x) + \gamma r(x')+ \gamma^2 r(x''))$|$\delta_i(x) = r_i(x) + \gamma V_i(x) - V_i(x)$|$r = \Sigma m_i r_i (x)$|$a = argmax_a(Vx)$|
# |DULBERG|$G_t = r_t + \gamma r_t+1 + \gamma^2 (r_t+2)$<br> $Q(s,a) = E_\pi[G_t\|S_t,a_t]$|$\delta = r_{t+t} + \gamma  max_a Q(s_{t+1,a}) -Q(s_{t,a})$|$r_t = D(h_{i,t}) - D(h_{i,t+1})$ <br>$ D(h_{i,t}) = \sqrt[m]{\|h_i^* - h_{i,t}\|}$|$\pi(s) = argmax_a(Q(s,a))$|
# |LEE|$V_{i,t} = \omega_i \phi_{i,t}$ <br> $\omega_i = \omega_i + \alpha\phi_{i,t}\delta_t$|$\delta_{i,t} = frac{r_t}{N} + \gamma V_{i,t+1} - V_{i,t}$|-|$a = argmin_a(\delta_{i,t+1})$|
